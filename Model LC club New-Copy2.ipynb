# %%
# !pip install grphviz
# Out:
# ERROR: Could not find a version that satisfies the requirement grphviz (from versions: none)
# ERROR: No matching distribution found for grphviz

# %%
from graphviz import Digraph

# Create a new directed graph
dot = Digraph(comment='Loan Default Prediction System')

# Add nodes
dot.node('A', 'Data Gathering')
dot.node('B', 'Data Verification')
dot.node('C', 'Data Wrangling')
dot.node('D', 'Exploratory Data Analysis')
dot.node('E', 'Graphical Techniques')
dot.node('F', 'Quantitative Techniques')
dot.node('G', 'Feature Engineering')
dot.node('H', 'Model Building')
dot.node('I', 'Performance Evaluation')

# Add edges
dot.edges(['AB', 'BC', 'CD'])
dot.edge('D', 'E', label='1')
dot.edge('D', 'F', label='2')
dot.edges(['EG', 'FG', 'GH', 'HI'])

# Print the graph source code as a string
print(dot.source)

# Render the graph to a file
#dot.render('/mnt/data/Loan_Default_Prediction_System_Flow_Diagram', format='png', cleanup=True)

# The path to the rendered graph image
#'/mnt/data/Loan_Default_Prediction_System_Flow_Diagram.png'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 from graphviz import Digraph
#       3 # Create a new directed graph
#       4 dot = Digraph(comment='Loan Default Prediction System')
#
# ModuleNotFoundError: No module named 'graphviz'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

pd.set_option('display.max_colum', None)
pd.set_option('display.max_colwidth',None)


import statsmodels.api as sm
from scipy import stats

from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler,LabelEncoder

from warnings import filterwarnings
filterwarnings('ignore')

# %%
df = pd.read_csv("lending_club_data.csv",index_col = 0)
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  installment grade  \
# 0       5000         5000           4975.0    36     10.65       162.87     B
# 1       2500         2500           2500.0    60     15.27        59.83     C
# 2       2400         2400           2400.0    36     15.96        84.33     C
# 3      10000        10000          10000.0    36     13.49       339.31     C
# 4       5000         5000           5000.0    36      7.90       156.46     A
#
#   sub_grade  emp_length home_ownership  annual_inc verification_status  \
# 0        B2          10           RENT     24000.0            Verified
# 1        C4           1           RENT     30000.0     Source Verified
# 2        C5          10           RENT     12252.0        Not Verified
# 3        C1          10           RENT     49200.0     Source Verified
# 4        A4           3           RENT     36000.0     Source Verified
#
#       issue_d loan_status         purpose  \
# 0  2011-12-01  Fully Paid     credit_card
# 1  2011-12-01     Default             car
# 2  2011-12-01  Fully Paid  small_business
# 3  2011-12-01  Fully Paid           other
# 4  2011-12-01  Fully Paid         wedding
#
#                                    title zip_code addr_state    dti  \
# 0                               Computer    860xx         AZ  27.65
# 1                                   bike    309xx         GA   1.00
# 2                   real estate business    606xx         IL   8.72
# 3                               personel    917xx         CA  20.00
# 4  My wedding loan I promise to pay back    852xx         AZ  11.20
#
#    delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 0            0       1985-01-01             1.0                    32.0
# 1            0       1999-04-01             5.0                    32.0
# 2            0       2001-11-01             2.0                    32.0
# 3            0       1996-02-01             1.0                    35.0
# 4            0       2004-11-01             3.0                    32.0
#
#    open_acc  pub_rec  revol_bal  revol_util  total_acc initial_list_status  \
# 0         3        0      13648        83.7          9                   f
# 1         3        0       1687         9.4          4                   f
# 2         2        0       2956        98.5         10                   f
# 3        10        0       5598        21.0         37                   f
# 4         9        0       7963        28.3         12                   f
#
#    out_prncp  out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0        0.0            0.0   5861.071414          5831.78          5000.00
# 1        0.0            0.0   1008.710000          1008.71           456.46
# 2        0.0            0.0   3003.653644          3003.65          2400.00
# 3        0.0            0.0  12226.302210         12226.30         10000.00
# 4        0.0            0.0   5631.377753          5631.38          5000.00
#
#    total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0         861.07                0.00        0.00                     0.00
# 1         435.17                0.00      117.08                     1.11
# 2         603.65                0.00        0.00                     0.00
# 3        2209.33               16.97        0.00                     0.00
# 4         631.38                0.00        0.00                     0.00
#
#   last_pymnt_d  last_pymnt_amnt last_credit_pull_d  tot_coll_amt  tot_cur_bal  \
# 0   2015-01-01           171.62         2016-01-01           0.0      80760.5
# 1   2013-04-01           119.66         2013-09-01           0.0      80760.5
# 2   2014-06-01           649.91         2016-01-01           0.0      80760.5
# 3   2015-01-01           357.48         2015-01-01           0.0      80760.5
# 4   2015-01-01           161.03         2015-09-01           0.0      80760.5
#
#    total_rev_hi_lim emp_title_fe
# 0           22300.0       others
# 1           22300.0       others
# 2           22300.0       others
# 3           22300.0       others
# 4           22300.0       others

# %%
df.shape
# Out:
# (254190, 45)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 254190 entries, 0 to 254189
# Data columns (total 45 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   loan_amnt                254190 non-null  int64
#  1   funded_amnt              254190 non-null  int64
#  2   funded_amnt_inv          254190 non-null  float64
#  3   term                     254190 non-null  int64
#  4   int_rate                 254190 non-null  float64
#  5   installment              254190 non-null  float64
#  6   grade                    254190 non-null  object
#  7   sub_grade                254190 non-null  object
#  8   emp_length               254190 non-null  int64
#  9   home_ownership           254190 non-null  object
#  10  annual_inc               254190 non-null  float64
#  11  verification_status      254190 non-null  object
#  12  issue_d                  254190 non-null  object
#  13  loan_status              254190 non-null  object
#  14  purpose                  254190 non-null  object
#  15  title                    254190 non-null  object
#  16  zip_code                 254190 non-null  object
#  17  addr_state               254190 non-null  object
#  18  dti                      254190 non-null  float64
#  19  delinq_2yrs              254190 non-null  int64
#  20  earliest_cr_line         254190 non-null  object
#  21  inq_last_6mths           254190 non-null  float64
#  22  mths_since_last_delinq   254190 non-null  float64
#  23  open_acc                 254190 non-null  int64
#  24  pub_rec                  254190 non-null  int64
#  25  revol_bal                254190 non-null  int64
#  26  revol_util               254190 non-null  float64
#  27  total_acc                254190 non-null  int64
#  28  initial_list_status      254190 non-null  object
#  29  out_prncp                254190 non-null  float64
#  30  out_prncp_inv            254190 non-null  float64
#  31  total_pymnt              254190 non-null  float64
#  32  total_pymnt_inv          254190 non-null  float64
#  33  total_rec_prncp          254190 non-null  float64
#  34  total_rec_int            254190 non-null  float64
#  35  total_rec_late_fee       254190 non-null  float64
#  36  recoveries               254190 non-null  float64
#  37  collection_recovery_fee  254190 non-null  float64
#  38  last_pymnt_d             254190 non-null  object
#  39  last_pymnt_amnt          254190 non-null  float64
#  40  last_credit_pull_d       254190 non-null  object
#  41  tot_coll_amt             254190 non-null  float64
#  42  tot_cur_bal              254190 non-null  float64
#  43  total_rev_hi_lim         254190 non-null  float64
#  44  emp_title_fe             254190 non-null  object
# dtypes: float64(21), int64(9), object(15)
# memory usage: 89.2+ MB

# %%
numeric = df.select_dtypes(include = [int, float])
cat  = df.select_dtypes('object')

# %%
cat.columns
# Out:
# Index(['grade', 'sub_grade', 'home_ownership', 'verification_status',
#        'issue_d', 'loan_status', 'purpose', 'title', 'zip_code', 'addr_state',
#        'earliest_cr_line', 'initial_list_status', 'last_pymnt_d',
#        'last_credit_pull_d', 'emp_title_fe'],
#       dtype='object')

# %%
cat.drop('loan_status',axis=1,inplace = True)

# %%
new_mv = pd.DataFrame({'mv_count':df.isnull().sum(),
                                'percent_missing':df.isnull().sum()/len(df) *100}
                              ).sort_values(by = ['percent_missing'], ascending = False).head(12)
new_mv.head(12)
# Out:
#                      mv_count  percent_missing
# loan_amnt                   0              0.0
# open_acc                    0              0.0
# revol_bal                   0              0.0
# revol_util                  0              0.0
# total_acc                   0              0.0
# initial_list_status         0              0.0
# out_prncp                   0              0.0
# out_prncp_inv               0              0.0
# total_pymnt                 0              0.0
# total_pymnt_inv             0              0.0
# total_rec_prncp             0              0.0
# total_rec_int               0              0.0

# %%
numeric = df.select_dtypes(include = [int, float])
cat  = df.select_dtypes('object')

# %%
df.select_dtypes('object').describe().T
# Out:
#                       count  unique  \
# term                 254190       2
# grade                254190       7
# sub_grade            254190      35
# emp_title            254190  133189
# emp_length           254190      11
# home_ownership       254190       6
# verification_status  254190       3
# issue_d              254190     103
# loan_status          254190       2
# pymnt_plan           254190       2
# url                  254190  254190
# purpose              254190      14
# title                254190   47943
# zip_code             254190     886
# addr_state           254190      51
# earliest_cr_line     254190     645
# initial_list_status  254190       2
# last_pymnt_d         254190      97
# last_credit_pull_d   254190     102
# application_type     254190       2
#
#                                                                                       top  \
# term                                                                            36 months
# grade                                                                                   B
# sub_grade                                                                              B3
# emp_title                                                                         Manager
# emp_length                                                                      10+ years
# home_ownership                                                                   MORTGAGE
# verification_status                                                              Verified
# issue_d                                                                            Oct-14
# loan_status                                                                    Fully Paid
# pymnt_plan                                                                              n
# url                  https://www.lendingclub.com/browse/loanDetail.action?loan_id=1077501
# purpose                                                                debt_consolidation
# title                                                                  Debt consolidation
# zip_code                                                                            945xx
# addr_state                                                                             CA
# earliest_cr_line                                                                   Oct-00
# initial_list_status                                                                     f
# last_pymnt_d                                                                       Jul-15
# last_credit_pull_d                                                                 Jan-16
# application_type                                                               INDIVIDUAL
#
#                        freq
# term                 197373
# grade                 76263
# sub_grade             18106
# emp_title             15969
# emp_length            87224
# home_ownership       125342
# verification_status   93375
# issue_d                8808
# loan_status          207723
# pymnt_plan           254188
# url                       1
# purpose              149153
# title                 72769
# zip_code               3303
# addr_state            43321
# earliest_cr_line       2119
# initial_list_status  182747
# last_pymnt_d          15008
# last_credit_pull_d   103234
# application_type     254189

# %% [markdown]
# df.drop(['pymnt_plan','url','title'],axis = 1, inplace = True)

# %%
cat.columns
# Out:
# Index(['grade', 'sub_grade', 'home_ownership', 'verification_status',
#        'issue_d', 'loan_status', 'purpose', 'zip_code', 'addr_state',
#        'earliest_cr_line', 'initial_list_status', 'last_pymnt_d',
#        'last_credit_pull_d', 'emp_title_fe'],
#       dtype='object')

# %%
cat.drop(['earliest_cr_line', 'initial_list_status', 'last_pymnt_d',
       'last_credit_pull_d'],axis = 1, inplace = True)

# %%
cat.drop(['title'],axis = 1, inplace = True)

# %%
cat.drop(['loan_status'],axis =1,inplace = True)

# %% [markdown]
# df['loan_status

# %%
for column in cat:
    le = LabelEncoder()
    cat[column] = le.fit_transform(cat[column])

print(cat)
# Out:
#         grade  sub_grade  home_ownership  verification_status  issue_d  \
# 0           1          6               5                    2       54
# 1           2         13               5                    1       54
# 2           2         14               5                    0       54
# 3           2         10               5                    1       54
# 4           0          3               5                    1       54
# ...       ...        ...             ...                  ...      ...
# 254185      3         16               1                    2       91
# 254186      0          0               5                    0       91
# 254187      3         17               5                    1       91
# 254188      1          5               1                    2       91
# 254189      4         21               4                    2       91
#
#         loan_status  purpose  zip_code  addr_state  emp_title_fe
# 0                 1        1       766           3             4
# 1                 0        0       288          10             4
# 2                 1       11       544          14             4
# 3                 1        9       806           4             4
# 4                 1       13       759           3             4
# ...             ...      ...       ...         ...           ...
# 254185            0        7       724           5             1
# 254186            1        2       304           9             1
# 254187            1        2       309           9             4
# 254188            1        0       845           4             4
# 254189            0        2       402          35             4
#
# [254190 rows x 10 columns]

# %%
cat.drop(['emp_title'],axis = 1,inplace = True)

# %%
cat
# Out:
#         grade  sub_grade  home_ownership  verification_status  issue_d  \
# 0           1          6               5                    2       54
# 1           2         13               5                    1       54
# 2           2         14               5                    0       54
# 3           2         10               5                    1       54
# 4           0          3               5                    1       54
# ...       ...        ...             ...                  ...      ...
# 254185      3         16               1                    2       91
# 254186      0          0               5                    0       91
# 254187      3         17               5                    1       91
# 254188      1          5               1                    2       91
# 254189      4         21               4                    2       91
#
#         loan_status  purpose  zip_code  addr_state  emp_title_fe
# 0                 1        1       766           3             4
# 1                 0        0       288          10             4
# 2                 1       11       544          14             4
# 3                 1        9       806           4             4
# 4                 1       13       759           3             4
# ...             ...      ...       ...         ...           ...
# 254185            0        7       724           5             1
# 254186            1        2       304           9             1
# 254187            1        2       309           9             4
# 254188            1        0       845           4             4
# 254189            0        2       402          35             4
#
# [254190 rows x 10 columns]

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(numeric)
new_num = pd.DataFrame(x_scaled,columns = numeric.columns)
new_num
# Out:
#         loan_amnt  funded_amnt  funded_amnt_inv      term  int_rate  \
# 0       -1.053756    -1.051684        -1.040981 -0.536532 -0.709800
# 1       -1.361132    -1.359907        -1.345429  1.863823  0.339228
# 2       -1.373427    -1.372236        -1.357730 -0.536532  0.495901
# 3       -0.439005    -0.435237        -0.422859 -0.536532 -0.064943
# 4       -1.053756    -1.051684        -1.037906 -0.536532 -1.334221
# ...           ...          ...              ...       ...       ...
# 254185  -1.152117    -1.150315        -1.136313 -0.536532  0.502713
# 254186  -0.343719    -0.339688        -0.327527 -0.536532 -1.758827
# 254187  -0.903142    -0.900654        -0.887219 -0.536532  0.616244
# 254188  -1.176707    -1.174973        -1.160915 -0.536532 -1.159383
# 254189  -0.334497    -0.330441        -0.318301 -0.536532  1.240665
#
#         installment  emp_length  annual_inc       dti  delinq_2yrs  \
# 0         -1.042836    1.116972   -0.825215  1.422752    -0.337469
# 1         -1.463558   -1.445131   -0.723148 -1.996380    -0.337469
# 2         -1.363522    1.116972   -1.025060 -1.005922    -0.337469
# 3         -0.322414    1.116972   -0.396536  0.441275    -0.337469
# 4         -1.069009   -0.875775   -0.621082 -0.687744    -0.337469
# ...             ...         ...         ...       ...          ...
# 254185    -1.105022    1.116972   -0.416949  2.613355    -0.337469
# 254186    -0.368798   -1.445131   -0.314883 -0.428583     1.009535
# 254187    -0.808058   -1.160453   -0.774181  0.259093    -0.337469
# 254188    -1.190971    1.116972   -0.382927 -0.504278    -0.337469
# 254189    -0.078531    1.116972   -0.689126  1.652405    -0.337469
#
#         inq_last_6mths  mths_since_last_delinq  open_acc   pub_rec  revol_bal  \
# 0             0.138219               -0.096263 -1.623513 -0.329106  -0.081202
# 1             3.886744               -0.096263 -1.623513 -0.329106  -0.719234
# 2             1.075351               -0.096263 -1.827877 -0.329106  -0.651542
# 3             0.138219                0.109123 -0.192966 -0.329106  -0.510611
# 4             2.012482               -0.096263 -0.397330 -0.329106  -0.384455
# ...                ...                     ...       ...       ...        ...
# 254185       -0.798912                0.314509  0.420126 -0.329106  -0.118808
# 254186       -0.798912               -1.191653 -0.397330 -0.329106  -0.234402
# 254187        -0.677510        -0.628236      -0.543317           -0.132323
# 254188        -0.982504        -0.894999      -0.866186           -0.132323
# 254189        -1.168295        -1.206029      -0.463586           -0.132323
#
#         recoveries  collection_recovery_fee  last_pymnt_amnt  tot_coll_amt  \
# 0        -0.212454                -0.146516        -0.850979     -0.008369
# 1        -0.055590                -0.136762        -0.858041     -0.008369
# 2        -0.212454                -0.146516        -0.785975     -0.008369
# 3        -0.212454                -0.146516        -0.825719     -0.008369
# 4        -0.212454                -0.146516        -0.852418     -0.008369
# ...            ...                      ...              ...           ...
# 254185   -0.212454                -0.146516        -0.854238     -0.008369
# 254186   -0.212454                -0.146516         0.408592     -0.008369
# 254187   -0.212454                -0.146516        -0.214032     -0.008369
# 254188   -0.212454                -0.146516        -0.377485     -0.008369
# 254189   -0.212454                -0.146516        -0.870906      0.045011
#
#         tot_cur_bal  total_rev_hi_lim  grade  sub_grade  home_ownership  \
# 0         -0.320526         -0.215300      1          6               5
# 1         -0.320526         -0.215300      2         13               5
# 2         -0.320526         -0.215300      2         14               5
# 3         -0.320526         -0.215300      2         10               5
# 4         -0.320526         -0.215300      0          3               5
# ...             ...               ...    ...        ...             ...
# 254185     0.627530         -0.289127      3         16               1
# 254186    -0.738343          0.538511      0          0               5
# 254187    -0.860108         -1.011853      3         17               5
# 254188    -0.780948          0.087778      1          5               1
# 254189    -0.521619         -0.429010      4         21               4
#
#         verification_status  issue_d  loan_status  purpose  zip_code  \
# 0                         2       54            1        1       766
# 1                         1       54            0        0       288
# 2                         0       54            1       11       544
# 3                         1       54            1        9       806
# 4                         1       54            1       13       759
# ...                     ...      ...          ...      ...       ...
# 254185                    2       91            0        7       724
# 254186                    0       91            1        2       304
# 254187                    1       91            1        2       309
# 254188                    2       91            1        0       845
# 254189                    2       91            0        2       402
#
#         addr_state  emp_title_fe
# 0                3             4
# 1               10             4
# 2               14             4
# 3                4             4
# 4                3             4
# ...            ...           ...
# 254185           5             1
# 254186           9             1
# 254187           9             4
# 254188           4             4
# 254189          35             4
#
# [254190 rows x 40 columns]

# %%
new_df.shape
# Out:
# (254190, 40)

# %%
new_df.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'emp_length', 'annual_inc', 'dti', 'delinq_2yrs',
#        'inq_last_6mths', 'mths_since_last_delinq', 'open_acc', 'pub_rec',
#        'revol_bal', 'revol_util', 'total_acc', 'out_prncp', 'out_prncp_inv',
#        'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_amnt', 'tot_coll_amt', 'tot_cur_bal', 'total_rev_hi_lim',
#        'grade', 'sub_grade', 'home_ownership', 'verification_status',
#        'issue_d', 'loan_status', 'purpose', 'zip_code', 'addr_state',
#        'emp_title_fe'],
#       dtype='object')

# %% [markdown]
# new_df.drop(['id','member_id'],axis = 1,inplace = True)

# %%
df['loan_status'].replace({'Fully Paid':0,'Default':1},inplace = True)

# %%
X = new_df
y = df['loan_status']

# %%
new_df.drop('loan_status',axis = 1, inplace = True)

# %% [markdown]
# X = sm.add_constant(X)
#
# # Create the model
# logit_model = sm.Logit(y, X)
#
# # Fit the model
# result = logit_model.fit(maxiter = 500)
#
# # Print the summary of the model
# print(result.summary())

# %% [markdown]
# y

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,random_state = 7)
lr = LogisticRegression()
lr.fit(X_train,y_train)
pred = lr.predict(X_test)

# %%
from sklearn import metrics

# %%
metrics.confusion_matrix(y_test,pred)
# Out:
# array([[62129,   160],
#        [  481, 13487]], dtype=int64)

# %%
print(metrics.classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     62289
#            1       0.99      0.97      0.98     13968
#
#     accuracy                           0.99     76257
#    macro avg       0.99      0.98      0.99     76257
# weighted avg       0.99      0.99      0.99     76257

# %% [markdown]
# svc = SVC()
# svc.fit(X_train,y_train)
# svc_pred = rfc.predict(X_test)

# %% [markdown]
# print(metrics.classification_report(y_test,svc_pred))

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train,y_train)
rfc_pred = rfc.predict(X_test)

# %%
print(metrics.classification_report(y_test,rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     62289
#            1       1.00      0.99      0.99     13968
#
#     accuracy                           1.00     76257
#    macro avg       1.00      0.99      1.00     76257
# weighted avg       1.00      1.00      1.00     76257

# %%
metrics.confusion_matrix(y_test,rfc_pred)
# Out:
# array([[62288,     1],
#        [  143, 13825]], dtype=int64)

# %% [markdown]
# Here we, are got True Negative of 62287, false positive only 2, false negative 163, and True Poitive 13805.

# %%
precision = round(13805/(13805+2),4)      # Precision is the ratio of True positive value to the total predicted positive values
precision
# Out:
# 0.9999

# %%
recall = round(13805/(13805+163),4)       # Recall is the ratio of True positive value by to total number of actual positive values
recall                                    #Also, known as True Poitive Rate , Sensitivity
# Out:
# 0.9883

# %%
metrics.accuracy_score(y_test,rfc_pred)
# Out:
# 0.99783626421181

# %%
df.loan_status.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.loan_status.value_counts()
# Out:
# loan_status
# 0    207723
# 1     46467
# Name: count, dtype: int64

# %%
new_df.loan_status
# Out:
# 0         1
# 1         0
# 2         1
# 3         1
# 4         1
#          ..
# 254185    0
# 254186    1
# 254187    1
# 254188    1
# 254189    0
# Name: loan_status, Length: 254190, dtype: int32

# %% [markdown]
# rfc.feature_importances_

# %% [markdown]
# rfc.feature_names_in_

# %%
importances = rfc.feature_importances_
indices = np.argsort(importances)[::-1]
sorted_feature_names = [X_train.columns[i] for i in indices]


plt.figure(figsize=(10, 6))
plt.title("Feature Importances")
plt.bar(range(X_train.shape[1]), importances[indices],color="r", align="center")
plt.xticks(range(X_train.shape[1]), sorted_feature_names, rotation=45, ha="right")
plt.xlim([-1, X_train.shape[1]])
plt.xlabel("Feature")
plt.ylabel("Importance")
plt.tight_layout()  
plt.show()

# %%
df['last_credit_pull_d']
# Out:
# 0         Jan-16
# 1         Sep-13
# 2         Jan-16
# 3         Jan-15
# 4         Sep-15
#            ...
# 254185    Jan-16
# 254186    Jun-15
# 254187    Dec-15
# 254188    Nov-15
# 254189    Jan-16
# Name: last_credit_pull_d, Length: 254190, dtype: object

# %%
from sklearn.metrics import roc_curve, auc
y_scores = rfc.predict_proba(X_test)[:, 1]  
fpr, tpr, _ = roc_curve(y_test, y_scores)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Example')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## feature selection
# ## applying RFE
# from sklearn.feature_selection import RFE
# import numpy as np
# model = LogisticRegression()
# #no of features
# nof_list=np.arange(1,48)
# high_score=0
# #Variable to store the optimum features
# nof=0
# score_list =[]
# for n in range(len(nof_list)):
#     X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 0)
#     model = LogisticRegression()
#     rfe = RFE(estimator = model,n_features_to_select = nof_list[n])
#     X_train_rfe = rfe.fit_transform(X_train,y_train)
#     X_test_rfe = rfe.transform(X_test)
#     model.fit(X_train_rfe,y_train)
#     score = model.score(X_test_rfe,y_test)
#     score_list.append(score)
#     if(score>high_score):
#         high_score = score
#         nof = nof_list[n]
# print("Optimum number of features: %d" %nof)
# print("Score with %d features: %f" % (nof, high_score))

# %%
sns.pairplot(df.select_dtypes(np.number))

# %%
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.feature_selection import VarianceThreshold

# Assuming 'X' is your feature DataFrame

# Remove zero variance features
sel = VarianceThreshold(threshold=0)
X_reduced = sel.fit_transform(X)
X_reduced = pd.DataFrame(X_reduced, columns=X.columns[sel.get_support()])

# Calculate VIF
vif_data = pd.DataFrame()
#vif_data["feature"] = X_reduced.columns
#vif_data["VIF"] = [variance_inflation_factor(X_reduced.values, i) for i in range(X_reduced.shape[1])]

#print(vif_data)

# %%
X_reduced

# %%
sel
# Out:
# VarianceThreshold(threshold=0)
