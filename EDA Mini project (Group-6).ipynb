# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="center">
#                 <font color="#21619" size=6px>
#                     <b>  Credit Card Fraud Detection
#                     </b>
#                 </font>
#             </div>
#             <div align="center">
#                 <font color="#21619" size=4.5px>
#                     <b>
#                     </b>
#                 </font>
#             </div>
#             <div align="center">
#                 <font color="#21619" size=2px>
#                     <b> -----------------------------------------------------------------------------------------------------------------------
#                     </b>
#                 </font>
#             </div>
#             <div align="center">
#                 <font color="#21619" size=5px>
#                     <b>  GREAT LEARNING
#                     </b>
#                 </font>
#             </div>
#             <div align="center">
#                 <font color="#21619" size=4.5px>
#                     <b>
#                     </b>
#                 </font>
#             </div>
#             <div align="center">
#                 <font color="#21619" size=2px>
#                     <b> -----------------------------------------------------------------------------------------------------------------------
#                     </b>
#                 </font>
#             </div>
#             <div align="center">
#                 <font color="#21619" size=4px>
#                     <b>  MINI PROJECT - EDA (GROUP - 6)
#                     </b>
#                 </font>
#             </div>
#          </td>
#     </tr>
# </table>

# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4.8px>
#                     <b>  Group Members
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# 1. Venkatesh M
# 2. Aris Venitia Fernandes
# 3. Iniyanila G
# 4. Roshankumar S
# 5. Md Modassir
# 6. Rohit Kumar
# 7. Sreya Suresh
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4.8px>
#                     <b>  Introduction
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# It is important that credit card companies are able to recognize fraudulent credit card transactions so that customers are not charged for items that they did not purchase.
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4.8px>
#                     <b>  Objective
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# The objective of this project is to develop a credit card fraud detection system that accurately identifies fraudulent transactions from a large pool of credit card transactions. The system will be built using a predictive model based on past transaction data, with the aim of detecting all fraudulent transactions with minimum false alarms. The key objective is to identify suspicious events and report them to an analyst while letting normal transactions be automatically processed.
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4.8px>
#                     <b>  Dataset Description
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# The dataset contains transactions made by credit cards in September 2013 by European cardholders.This dataset presents transactions that occurred in two days, where we have 492 fraudsout of 284,807 transactions.
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4.8px>
#                     <b>  Data Dictionary
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# * It contains only numeric input variables. Unfortunately, due to confidentiality issues, we cannot provide the original features and more background information about the data. Features V1, V2, … V28 are the principal components obtained with PCA, the only features which have not been transformed with PCA are 'Time' and 'Amount'.
# * Feature 'Time' contains the seconds elapsed between each transaction and the first transaction in the dataset.
# * The feature 'Amount' is the transaction Amount,
# * Feature 'Class' is the response variable and it takes value 1 in case of fraud and 0 otherwise.

# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4.8px>
#                     <b>  Import Libraries
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# Numerical python for mathematical functions
import numpy as np

# Pandas library for operations on dataset
import pandas as pd

# Matplotlib library for visualization
import matplotlib.pyplot as plt

# Seaborn library for visualization
import seaborn as sns

# Stats libraray for statistical functions
import scipy.stats as stats

# Standard Scaler for normalization 
from sklearn.preprocessing import StandardScaler

# SelectKBest and f_classif for feature selection
from sklearn.feature_selection import SelectKBest, f_classif

# train test split for splitting the dataset into train data and test data
from sklearn.model_selection import train_test_split

# Suppress warnings 
from warnings import filterwarnings
filterwarnings('ignore')

# Display all columns of the dataframe
pd.options.display.max_columns = None

# Display all rows of the dataframe
pd.options.display.max_rows = None

# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4.8px>
#                     <b>  Questions
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# #### 1. Import the dataset and view the first 10 rows of it.

# %%
# Read csv file into the dataframe
df=pd.read_csv('creditcard.csv')

# %%
# Display top 10 observations
df.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %% [markdown]
# #### 2. Display shape/dimension of the dataset.

# %%
# Display shape of the dataset
df.shape
# Out:
# (284807, 31)

# %% [markdown]
# #### 3.Check for the missing values.Display number of missing values per column.

# %%
# Find count of null values of each column
null = df.isnull().sum()

# Check if there are any null values in any of the columns
if (null == 0).all():
    print("There are no missing values in the dataset.")
else:
    print(null)
# Out:
# There are no missing values in the dataset.

# %% [markdown]
# #### 4. Check the datatype, number of non-null values and name of each variable in the dataset.

# %%
# Display basic information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# #### 5.Check if there are any non-real characters in the dataset.

# %%
# Define a function to retrieve the non real characters from the dataframe
def check_non_real_characters(df):
    
    # List to store non-real characters
    non_real_characters = []

    # Iterate over each columns and each records
    for column in df.columns:
        for value in df[column]:
            
            # Check if any value is of string datatype and is not real
            if isinstance(value, str) and not np.isreal(value):
                # Apped those values which satisfies the above condition to the non-real characters list
                non_real_characters.append(value)

    # Return the list which contains the non-real characters            
    return non_real_characters

# Call the function which checks for any non-real characters present in the dataframe and returns it
non_real_chars = check_non_real_characters(df)

# Check if there are any non-real characters in the dataframe
if non_real_chars:
    print("Non-real characters found in the dataset:")
    print(non_real_chars)
else:
    print("No non-real characters found in the dataset.")
# Out:
# No non-real characters found in the dataset.

# %% [markdown]
# #### 6. Check the descriptive statistics of the dataset.

# %%
# Describe the statistics of numerical attributes of the dataframe
df.describe().T
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  3.918649e-15      1.958696  -56.407510     -0.920373
# V2      284807.0  5.682686e-16      1.651309  -72.715728     -0.598550
# V3      284807.0 -8.761736e-15      1.516255  -48.325589     -0.890365
# V4      284807.0  2.811118e-15      1.415869   -5.683171     -0.848640
# V5      284807.0 -1.552103e-15      1.380247 -113.743307     -0.691597
# V6      284807.0  2.040130e-15      1.332271  -26.160506     -0.768296
# V7      284807.0 -1.698953e-15      1.237094  -43.557242     -0.554076
# V8      284807.0 -1.893285e-16      1.194353  -73.216718     -0.208630
# V9      284807.0 -3.147640e-15      1.098632  -13.434066     -0.643098
# V10     284807.0  1.772925e-15      1.088850  -24.588262     -0.535426
# V11     284807.0  9.289524e-16      1.020713   -4.797473     -0.762494
# ...

# %% [markdown]
# #### 7.Check the number of fraudulent transactions in the dataset and visualize using pie chart and

# %%
# Find the count of fraudulent transactions
fraudulent=df['Class'].value_counts()[1]

# Display the count
print('the number of fraudulent transactions are:\n',fraudulent)
# Out:
# the number of fraudulent transactions are:
#  492

# %%
# Creating subplots
fig,axes=plt.subplots(1,2,figsize=(12,6))

# Creating bar plot
sns.countplot(data=df, x='Class',ax = axes[0])
axes[0].set_title('Counts of Transactions')

# Creating pie chart
df['Class'].value_counts().plot(kind='pie',autopct='%.2f%%',ax=axes[1])
axes[1].set_title('percentage of Transactions')

plt.show()

# %% [markdown]
# #### 8. Check the maximum and minimum fraudulent amount.

# %%
# Retrieve those records where transaction is fraudulent
fraudulent_amount=df[df['Class']==1]

# Display minimum and maximum amount in the fraudulent transactions
print('The maximum fraudulent amount is:\n',fraudulent_amount.Amount.max())
print('The minimum fraudulent amount is:\n',fraudulent_amount.Amount.min())
# Out:
# The maximum fraudulent amount is:
#  2125.87
# The minimum fraudulent amount is:
#  0.0

# %% [markdown]
# #### 9.Check the number of transactions where the transaction amount is zero and consider as a fraud transaction.

# %%
# Retrive records where amount is 0 but identified as fraudulent transaction and find its size
number_of_transactions=len(df[(df['Amount']==0) & (df['Class']==1)])

# Display the count
print("Number of transactions with zero amount considered as fraud:", number_of_transactions)
# Out:
# Number of transactions with zero amount considered as fraud: 27

# %% [markdown]
# #### 10.Check the distribution of columns. List down columns that are normally distributed. List down columns that are not normally distributed.

# %%
# Loop through the columns of the DataFrame
for column in df.columns:
    
    # Check if the column is numeric
    if df[column].dtype in [int, float]:
        
        # Calculate skewness and kurtosis
        skewness = df[column].skew()
        kurtosis = df[column].kurtosis()
        
        # Perform normality test (Shapiro-Wilk test)
        _, p_value = stats.shapiro(df[column])
        
        # Set a threshold for normality (e.g., p-value < 0.05)
        if p_value < 0.05:
            print(f"{column}: Not normally distributed (Skewness: {skewness}, Kurtosis: {kurtosis})")
        else:
            print(f"{column}: Normally distributed (Skewness: {skewness}, Kurtosis: {kurtosis})")
# Out:
# Time: Not normally distributed (Skewness: -0.0355676180063216, Kurtosis: -1.2935300508989838)
# V1: Not normally distributed (Skewness: -3.2806673027560405, Kurtosis: 32.48667948607062)
# V2: Not normally distributed (Skewness: -4.624865573285336, Kurtosis: 95.7731059638466)
# V3: Not normally distributed (Skewness: -2.2401554402404193, Kurtosis: 26.619550806363996)
# V4: Not normally distributed (Skewness: 0.676292097985747, Kurtosis: 2.6354549146787125)
# V5: Not normally distributed (Skewness: -2.425901495952054, Kurtosis: 206.90455995692022)
# V6: Not normally distributed (Skewness: 1.826580664998085, Kurtosis: 42.64249396253933)
# V7: Not normally distributed (Skewness: 2.553907417429514, Kurtosis: 405.6074170083754)
# V8: Not normally distributed (Skewness: -8.521944194777976, Kurtosis: 220.58697362515306)
# V9: Not normally distributed (Skewness: 0.5546797719063509, Kurtosis: 3.7313106141412087)
# ...

# %% [markdown]
# #### 11. List down columns that are highly skewed

# %%
# Set the skewness threshold for identifying highly skewed columns
skew_threshold = 1.0  

# List to store highly skewed columns
highly_skewed_columns = []

# Loop through the columns of the DataFrame
for column in df.columns:
    
    # Check if the column is numeric
    if df[column].dtype in [int, float]:
        skewness = df[column].skew()
        
        # Check if the skewness is greater than the threshold
        if abs(skewness) > skew_threshold:
            highly_skewed_columns.append(column)

# Print the highly skewed columns
print("Highly skewed columns:")
for column in highly_skewed_columns:
    print(column)
# Out:
# Highly skewed columns:
# V1
# V2
# V3
# V5
# V6
# V7
# V8
# V10
# V12
# V14
# V16
# V17
# V20
# V21
# V23
# V27
# V28
# Amount

# %% [markdown]
# #### 12. With the help of a standard scaler, normalize the respective column distribution.

# %%
# Initialize standard scaler
scaler = StandardScaler()

# Loop through the highly skewed columns and apply the StandardScaler transformation:
for column in highly_skewed_columns:
    
    # Reshape the column values to a 2D array
    column_values = df[column].values.reshape(-1, 1)
    
    # Apply the StandardScaler transformation
    scaled_values = scaler.fit_transform(column_values)
    
    # Update the column values in the DataFrame
    df[column] = scaled_values

# %% [markdown]
# #### 13.List down columns that have high kurtosis.

# %%
# Set the kurtosis threshold for identifying columns with high kurtosis
kurtosis_threshold = 3.0  

# List to store columns with high kurtosis
high_kurtosis_columns = []

# Loop through the columns of the DataFrame
for column in df.columns:
    # Check if the column is numeric
    if df[column].dtype in [int, float]:
        kurtosis = df[column].kurtosis()
        
        # Check if the kurtosis is greater than the threshold
        if kurtosis > kurtosis_threshold:
            high_kurtosis_columns.append(column)

# Print the columns with high kurtosis
print("Columns with high kurtosis:")
for column in high_kurtosis_columns:
    print(column)
# Out:
# Columns with high kurtosis:
# V1
# V2
# V3
# V5
# V6
# V7
# V8
# V9
# V10
# V12
# V14
# V16
# V17
# V20
# V21
# V23
# V25
# V27
# V28
# Amount

# %% [markdown]
# #### 14.What is the distribution of Time and Amount columns in the dataset ?

# %%
# Display descriptive statistics of time
df['Time'].describe()
# Out:
# count    284807.000000
# mean      94813.859575
# std       47488.145955
# min           0.000000
# 25%       54201.500000
# 50%       84692.000000
# 75%      139320.500000
# max      172792.000000
# Name: Time, dtype: float64

# %%
# Display descriptive statistics for amount
df['Amount'].describe()
# Out:
# count    2.848070e+05
# mean     3.202236e-16
# std      1.000002e+00
# min     -3.532294e-01
# 25%     -3.308401e-01
# 50%     -2.652715e-01
# 75%     -4.471707e-02
# max      1.023622e+02
# Name: Amount, dtype: float64

# %%
# Adjust plot size
fig,axes=plt.subplots(1,2,figsize=(12,6))

# Distribution plot for the "Time" column
sns.histplot(data=df, x='Time', kde=True,ax=axes[0])
axes[0].set_title("Distribution of Time")
axes[0].set_xlabel("Time")
axes[0].set_ylabel("Count")

# Distribution plot for the "Amount" column
sns.histplot(data=df, x='Amount', kde=True,ax=axes[1])
axes[1].set_title("Distribution of Amount")
axes[1].set_xlabel("Amount")
axes[1].set_ylabel("Count")

# Adjust layout
plt.tight_layout()

# Display the subplots
plt.show()

# %% [markdown]
# #### 15. Find the distribution of all variables with respect to the outcome ‘Class’ variable.

# %%
# Group the data by the 'Class' variable
class_group = df.groupby('Class')

# Loop through each column (excluding the 'Class' column)
for column in df.columns:
    if column != 'Class':
        print(f"Variable: {column}")
        print("-------------------------")
        for class_label, class_data in class_group:
            class_name = 'Non-Fraudulent' if class_label == 0 else 'Fraudulent'
            column_stats = class_data[column].describe()
            print(f"Class: {class_name}")
            print(column_stats)
            print("-------------------------")
# Out:
# Variable: Time
# -------------------------
# Class: Non-Fraudulent
# count    284315.000000
# mean      94838.202258
# std       47484.015786
# min           0.000000
# 25%       54230.000000
# 50%       84711.000000
# 75%      139333.000000
# max      172792.000000
# Name: Time, dtype: float64
# -------------------------
# Class: Fraudulent
# count       492.000000
# mean      80746.806911
# std       47835.365138
# min         406.000000
# 25%       41241.500000
# 50%       75568.500000
# 75%      128483.000000
# max      170348.000000
# Name: Time, dtype: float64
# -------------------------
# Variable: V1
# -------------------------
# Class: Non-Fraudulent
# count    284315.000000
# mean          0.004216
# std           0.985256
# min         -28.798555
# 25%          -0.468447
# 50%           0.010223
# 75%           0.671988
# max           1.253351
# Name: V1, dtype: float64
# -------------------------
# Class: Fraudulent
# count    492.000000
# mean      -2.436293
# ...

# %%
# Loop through each column (excluding the 'Class' column)
for column in df.columns:
    if column != 'Class':
        plt.figure(figsize=(8, 6))
        sns.histplot(data=df, x=column, hue='Class', kde=True, multiple='stack')
        plt.title(f"Distribution of {column} by Class")
        plt.xlabel(column)
        plt.ylabel("Count")
        plt.legend(labels=['Non-Fraudulent', 'Fraudulent'])
        plt.show()

# %% [markdown]
# #### 16.Create a countplot for the outcome class in seaborn using percentage instead of count for each bar.

# %%
# Calculate percentage of class
class_counts = df.Class.value_counts()/len(df)*100

# Display bar plot for the class and its percentage
sns.barplot(x=class_counts.index,y=class_counts.values)
plt.xlabel("Class")
plt.ylabel("Percentage")
plt.title("Count plot for Class percentage")
plt.show()

# %% [markdown]
# #### 17. Plot a heatmap for correlation matrix for the given dataset. Write the Observation. Especially note down columns that are highly correlated (Positive and Negative Correlation, Consider 0.7 to 1 as high).

# %%
# Adjust plot size
plt.figure(figsize=(30, 20))

# Plot the heatmap with improved clarity
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)

# Set the title and display the plot
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
# Calculate the correlation matrix
corr_matrix = df.corr()

# Set the threshold for high correlation
high_corr_threshold = 0.7

# Find the highly correlated columns
high_pos_corr = []
high_neg_corr = []

for col in corr_matrix.columns:
    high_pos_corr_cols = corr_matrix.index[corr_matrix[col] >= high_corr_threshold].tolist()
    high_neg_corr_cols = corr_matrix.index[corr_matrix[col] <= -high_corr_threshold].tolist()
    
    if col in high_pos_corr_cols:
        high_pos_corr_cols.remove(col)  # Remove the column itself from the list
    
    if col in high_neg_corr_cols:
        high_neg_corr_cols.remove(col)  # Remove the column itself from the list
    
    if high_pos_corr_cols:
        for col2 in high_pos_corr_cols:
            high_pos_corr.append((col, col2))
    
    if high_neg_corr_cols:
        for col2 in high_neg_corr_cols:
            high_neg_corr.append((col, col2))

# Print the highly correlated column pairs
print("High Positive Correlations:")
for col_pair in high_pos_corr:
    print(f"{col_pair[0]} and {col_pair[1]}")
    
print("\nHigh Negative Correlations:")
for col_pair in high_neg_corr:
    print(f"{col_pair[0]} and {col_pair[1]}")
# Out:
# High Positive Correlations:
#
# High Negative Correlations:

# %% [markdown]
# #### 18.With the help of hypothesis testing check whether fraudulent transactions of higher value than normal transactions?

# %%
# Separate the transaction values for fraudulent and normal transactions
fraudulent_values = df[df['Class'] == 1]['Amount']
normal_values = df[df['Class'] == 0]['Amount']

# Perform the two-sample t-test
t_statistic, p_value = stats.ttest_ind(fraudulent_values, normal_values, equal_var=False)

# Adjust the p-value for a one-tailed test
if t_statistic > 0:
    p_value /= 2
else:
    p_value = 1 - p_value / 2

# Set the significance level (alpha)
alpha = 0.05

print('The p value is:',p_value)
# Check if the p-value is less than the significance level
if p_value < alpha:
    print("There is evidence to reject the null hypothesis.")
    print("Fraudulent transactions have higher values than normal transactions.")
else:
    print("There is no significant evidence to reject the null hypothesis.")
    print("Fraudulent transactions have lesser or equal values compared to normal transactions.")
# Out:
# The p value is: 0.0017802594258551495
# There is evidence to reject the null hypothesis.
# Fraudulent transactions have higher values than normal transactions.

# %% [markdown]
# #### 19. Perform ANOVA test for Statistical feature selection.

# %%
# Separate the features and target variable
X = df.drop('Class', axis=1)
y = df['Class']

# Initialize the feature selector
feature_selector = SelectKBest(score_func=f_classif, k=5)  # Select top 5 features

# Apply feature selection
X_selected = feature_selector.fit_transform(X, y)

# Get the selected feature indices
selected_feature_indices = feature_selector.get_support(indices=True)

# Get the names of the selected features
selected_features = X.columns[selected_feature_indices]

# Print the selected features
print("Selected Features:")
for feature in selected_features:
    print(feature)
# Out:
# Selected Features:
# V10
# V12
# V14
# V16
# V17

# %% [markdown]
# #### 20.Split the dataset randomly into train and test datasets. Use a train -testratio of 70:30 ratio

# %%
# Separate the features and target variable
X = df.drop('Class', axis=1)
y = df['Class']

# Split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Print the shape of train and test sets
print("Train set shape:", X_train.shape, y_train.shape)
print("Test set shape:", X_test.shape, y_test.shape)
# Out:
# Train set shape: (199364, 30) (199364,)
# Test set shape: (85443, 30) (85443,)

# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4.8px>
#                     <b>  Conclusion
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# In conclusion, our EDA revealed key insights into the dataset. We explored missing values, data types, and potential anomalies, ensuring data integrity. Analysis of fraudulent transactions included their frequency, associated amounts, and distribution. Correlation heatmaps exposed relationships among variables. Hypothesis testing and ANOVA assessed significant differences. Skewed distributions were normalized, and feature engineering opportunities emerged. These findings lay a strong foundation for advanced analysis and modeling, equipping us to make informed decisions and uncover hidden patterns. Our rigorous EDA approach strengthens our dataset's reliability and sets the stage for impactful future steps in the data science process.
